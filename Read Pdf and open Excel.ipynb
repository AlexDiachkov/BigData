# %%
import pandas as pd

df = pd.read_excel('Графики.xlsx')
df
# Out:
#       Количество пользователей  Размер файла    RPS  \
# 0                           10           3.0   35.0
# 1                          100           3.0   28.0
# 2                          500           3.0   30.0
# 3                           10           5.0   19.0
# 4                          500           5.0   18.0
# 5                           10          11.0   11.0
# 6                          100          11.0   10.0
# 7                          500          11.0    5.0
# 8                          NaN           NaN    NaN
# 9                           10           3.0   40.0
# 10                         500           3.0   38.0
# 11                          10           5.0   22.0
# 12                         100           5.0   20.0
# 13                          10          11.0   10.0
# 14                         100          11.0    9.0
# 15                         NaN           NaN    NaN
# 16                         100           NaN   96.0
# 17                        1000           NaN   91.0
# 18                         NaN           NaN    NaN
# 19                          10           NaN  245.0
# 20                         500           NaN  311.0
# 21                         NaN           NaN    NaN
# 22                          10           NaN  275.0
# 23                         600           NaN  319.0
# 24                         NaN           NaN    NaN
# 25                         NaN           NaN    NaN
# 26                         NaN           NaN    NaN
# 27                         NaN           NaN    NaN
# 28                         NaN           NaN    NaN
# 29                         NaN           NaN    NaN
# 30                         NaN           NaN    NaN
# 31               ЗагрузкаФайла          20.0    NaN
# 32             СкачиваниеФайла          23.0    NaN
# 33            СоздатьЗаявкуЭБГ          93.5    NaN
# 34  ПолучитьДокументыДляЗаявки         278.0    NaN
# 35           ПолучитьЗаявкуЭБГ         297.0    NaN
#
#                   Тип операции  Среднее значение RPS   \
# 0                ЗагрузкаФайла                    NaN
# 1                ЗагрузкаФайла                   31.0
# 2                ЗагрузкаФайла                    NaN
# 3                ЗагрузкаФайла                   18.5
# 4                ЗагрузкаФайла                    NaN
# 5                ЗагрузкаФайла                    NaN
# 6                ЗагрузкаФайла                   10.5
# 7                ЗагрузкаФайла                    NaN
# 8                          NaN                    NaN
# 9              СкачиваниеФайла                   39.0
# 10             СкачиваниеФайла                    NaN
# 11             СкачиваниеФайла                   21.0
# 12             СкачиваниеФайла                    NaN
# 13             СкачиваниеФайла                    9.5
# 14             СкачиваниеФайла                    NaN
# 15                         NaN                    NaN
# 16            СоздатьЗаявкуЭБГ                    NaN
# 17            СоздатьЗаявкуЭБГ                    NaN
# 18                         NaN                    NaN
# 19  ПолучитьДокументыДляЗаявки                    NaN
# 20  ПолучитьДокументыДляЗаявки                    NaN
# 21                         NaN                    NaN
# 22           ПолучитьЗаявкуЭБГ                    NaN
# 23           ПолучитьЗаявкуЭБГ                    NaN
# 24                         NaN                    NaN
# 25                         NaN                    NaN
# 26                         NaN                    NaN
# 27                         NaN                    NaN
# 28                         NaN                    NaN
# 29                         NaN                    NaN
# 30                         NaN                    NaN
# 31                         NaN                    NaN
# 32                         NaN                    NaN
# 33                         NaN                    NaN
# 34                         NaN                    NaN
# 35                         NaN                    NaN
#
#     Среднее значение средних значений  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                                 NaN         NaN         NaN         NaN
# 1                                 NaN         NaN         NaN         NaN
# 2                                 NaN         NaN         NaN         NaN
# 3                           20.000000         NaN         NaN         NaN
# 4                                 NaN         NaN         NaN         NaN
# 5                                 NaN         NaN         NaN         NaN
# 6                                 NaN         NaN         NaN         NaN
# 7                                 NaN         NaN         NaN         NaN
# 8                                 NaN         NaN         NaN         NaN
# 9                                 NaN         NaN         NaN         NaN
# 10                          23.166667         NaN         NaN         NaN
# 11                                NaN         NaN         NaN         NaN
# 12                                NaN         NaN         NaN         NaN
# 13                                NaN         NaN         NaN         NaN
# 14                                NaN         NaN         NaN         NaN
# 15                                NaN         NaN         NaN         NaN
# 16                          93.500000         NaN         NaN         NaN
# 17                                NaN         NaN         NaN         NaN
# 18                                NaN         NaN         NaN         NaN
# 19                         278.000000         NaN         NaN         NaN
# 20                                NaN         NaN         NaN         NaN
# 21                                NaN         NaN         NaN         NaN
# 22                         297.000000         NaN         NaN         NaN
# 23                                NaN         NaN         NaN         NaN
# 24                                NaN         NaN         NaN         NaN
# 25                                NaN         NaN         NaN         NaN
# 26                                NaN         NaN         NaN         NaN
# 27                                NaN         NaN         NaN         NaN
# 28                                NaN         NaN         NaN         NaN
# 29                                NaN         NaN         NaN         NaN
# 30                                NaN         NaN         NaN         NaN
# 31                                NaN         NaN         NaN         NaN
# 32                                NaN         NaN         NaN         NaN
# 33                                NaN         NaN         NaN         NaN
# 34                                NaN         NaN         NaN         NaN
# 35                                NaN         NaN         NaN         NaN
#
#     Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0          NaN  ...          NaN          NaN          NaN          NaN
# 1          NaN  ...          NaN          NaN          NaN          NaN
# 2          NaN  ...          NaN          NaN          NaN          NaN
# 3          NaN  ...          NaN          NaN          NaN          NaN
# 4          NaN  ...          NaN          NaN          NaN          NaN
# 5          NaN  ...          NaN          NaN          NaN          NaN
# 6          NaN  ...          NaN          NaN          NaN          NaN
# 7          NaN  ...          NaN          NaN          NaN          NaN
# 8          NaN  ...          NaN          NaN          NaN          NaN
# 9          NaN  ...          NaN          NaN          NaN          NaN
# 10         NaN  ...          NaN          NaN          NaN          NaN
# 11         NaN  ...          NaN          NaN          NaN          NaN
# 12         NaN  ...          NaN          NaN          NaN          NaN
# 13         NaN  ...          NaN          NaN          NaN          NaN
# 14         NaN  ...          NaN          NaN          NaN          NaN
# 15         NaN  ...          NaN          NaN          NaN          NaN
# 16         NaN  ...          NaN          NaN          NaN          NaN
# 17         NaN  ...          NaN          NaN          NaN          NaN
# 18         NaN  ...          NaN          NaN          NaN          NaN
# 19         NaN  ...          NaN          NaN          NaN          NaN
# 20         NaN  ...          NaN          NaN          NaN          NaN
# 21         NaN  ...          NaN          NaN          NaN          NaN
# 22         NaN  ...          NaN          NaN          NaN          NaN
# 23         NaN  ...          NaN          NaN          NaN          NaN
# 24         NaN  ...          NaN          NaN          NaN          NaN
# 25         NaN  ...          NaN          NaN          NaN          NaN
# 26         NaN  ...          NaN          NaN          NaN          NaN
# 27         NaN  ...          NaN          NaN          NaN          NaN
# 28         NaN  ...          NaN          NaN          NaN          NaN
# 29         NaN  ...          NaN          NaN          NaN          NaN
# 30         NaN  ...          NaN          NaN          NaN          NaN
# 31         NaN  ...          NaN          NaN          NaN          NaN
# 32         NaN  ...          NaN          NaN          NaN          NaN
# 33         NaN  ...          NaN          NaN          NaN          NaN
# 34         NaN  ...          NaN          NaN          NaN          NaN
# 35         NaN  ...          NaN          NaN          NaN          NaN
#
#     Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN          NaN
# 20          NaN          NaN          NaN          NaN          NaN
# 21          NaN          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25          NaN          NaN          NaN          NaN          NaN
# 26          NaN          NaN          NaN          NaN          NaN
# 27          NaN          NaN          NaN          NaN          NaN
# 28          NaN          NaN          NaN          NaN          NaN
# 29          NaN          NaN          NaN          NaN          NaN
# 30          NaN          NaN          NaN          NaN          NaN
# 31          NaN          NaN          NaN          NaN          NaN
# 32          NaN          NaN          NaN          NaN          NaN
# 33          NaN          NaN          NaN          NaN          NaN
# 34          NaN          NaN          NaN          NaN          NaN
# 35          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 25
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
#
# [36 rows x 26 columns]

# %%
df['Тип операции'].count()
# Out:
# 20

# %%
df.loc[2, 'a'] = 11
df
# Out:
# <ipython-input-58-64b7c0c7475f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Тип операции'][8] = 'ЗагрузкаФайлаXXX'
#       Количество пользователей  Размер файла    RPS  \
# 0                           10           3.0   35.0
# 1                          100           3.0   28.0
# 2                          500           3.0   30.0
# 3                           10           5.0   19.0
# 4                          500           5.0   18.0
# 5                           10          11.0   11.0
# 6                          100          11.0   10.0
# 7                          500          11.0    5.0
# 8                          NaN           NaN    NaN
# 9                           10           3.0   40.0
# 10                         500           3.0   38.0
# 11                          10           5.0   22.0
# 12                         100           5.0   20.0
# 13                          10          11.0   10.0
# 14                         100          11.0    9.0
# 15                         NaN           NaN    NaN
# 16                         100           NaN   96.0
# 17                        1000           NaN   91.0
# 18                         NaN           NaN    NaN
# 19                          10           NaN  245.0
# 20                         500           NaN  311.0
# 21                         NaN           NaN    NaN
# 22                          10           NaN  275.0
# 23                         600           NaN  319.0
# 24                         NaN           NaN    NaN
# 25                         NaN           NaN    NaN
# 26                         NaN           NaN    NaN
# 27                         NaN           NaN    NaN
# 28                         NaN           NaN    NaN
# 29                         NaN           NaN    NaN
# 30                         NaN           NaN    NaN
# 31               ЗагрузкаФайла          20.0    NaN
# 32             СкачиваниеФайла          23.0    NaN
# 33            СоздатьЗаявкуЭБГ          93.5    NaN
# 34  ПолучитьДокументыДляЗаявки         278.0    NaN
# 35           ПолучитьЗаявкуЭБГ         297.0    NaN
#
#                   Тип операции  Среднее значение RPS   \
# 0                ЗагрузкаФайла                    NaN
# 1                ЗагрузкаФайла                   31.0
# 2                ЗагрузкаФайла                    NaN
# 3                ЗагрузкаФайла                   18.5
# 4                ЗагрузкаФайла                    NaN
# 5                ЗагрузкаФайла                    NaN
# 6                ЗагрузкаФайла                   10.5
# 7                ЗагрузкаФайла                    NaN
# 8             ЗагрузкаФайлаXXX                    NaN
# 9              СкачиваниеФайла                   39.0
# 10             СкачиваниеФайла                    NaN
# 11             СкачиваниеФайла                   21.0
# 12             СкачиваниеФайла                    NaN
# 13             СкачиваниеФайла                    9.5
# 14             СкачиваниеФайла                    NaN
# 15                         NaN                    NaN
# 16            СоздатьЗаявкуЭБГ                    NaN
# 17            СоздатьЗаявкуЭБГ                    NaN
# 18                         NaN                    NaN
# 19  ПолучитьДокументыДляЗаявки                    NaN
# 20  ПолучитьДокументыДляЗаявки                    NaN
# 21                         NaN                    NaN
# 22           ПолучитьЗаявкуЭБГ                    NaN
# 23           ПолучитьЗаявкуЭБГ                    NaN
# 24                         NaN                    NaN
# 25                         NaN                    NaN
# 26                         NaN                    NaN
# 27                         NaN                    NaN
# 28                         NaN                    NaN
# 29                         NaN                    NaN
# 30                         NaN                    NaN
# 31                         NaN                    NaN
# 32                         NaN                    NaN
# 33                         NaN                    NaN
# 34                         NaN                    NaN
# 35                         NaN                    NaN
#
#     Среднее значение средних значений  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                                 NaN         NaN         NaN         NaN
# 1                                 NaN         NaN         NaN         NaN
# 2                                 NaN         NaN         NaN         NaN
# 3                           20.000000         NaN         NaN         NaN
# 4                                 NaN         NaN         NaN         NaN
# 5                                 NaN         NaN         NaN         NaN
# 6                                 NaN         NaN         NaN         NaN
# 7                                 NaN         NaN         NaN         NaN
# 8                                 NaN         NaN         NaN         NaN
# 9                                 NaN         NaN         NaN         NaN
# 10                          23.166667         NaN         NaN         NaN
# 11                                NaN         NaN         NaN         NaN
# 12                                NaN         NaN         NaN         NaN
# 13                                NaN         NaN         NaN         NaN
# 14                                NaN         NaN         NaN         NaN
# 15                                NaN         NaN         NaN         NaN
# 16                          93.500000         NaN         NaN         NaN
# 17                                NaN         NaN         NaN         NaN
# 18                                NaN         NaN         NaN         NaN
# 19                         278.000000         NaN         NaN         NaN
# 20                                NaN         NaN         NaN         NaN
# 21                                NaN         NaN         NaN         NaN
# 22                         297.000000         NaN         NaN         NaN
# 23                                NaN         NaN         NaN         NaN
# 24                                NaN         NaN         NaN         NaN
# 25                                NaN         NaN         NaN         NaN
# 26                                NaN         NaN         NaN         NaN
# 27                                NaN         NaN         NaN         NaN
# 28                                NaN         NaN         NaN         NaN
# 29                                NaN         NaN         NaN         NaN
# 30                                NaN         NaN         NaN         NaN
# 31                                NaN         NaN         NaN         NaN
# 32                                NaN         NaN         NaN         NaN
# 33                                NaN         NaN         NaN         NaN
# 34                                NaN         NaN         NaN         NaN
# 35                                NaN         NaN         NaN         NaN
#
#     Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0          NaN  ...          NaN          NaN          NaN          NaN
# 1          NaN  ...          NaN          NaN          NaN          NaN
# 2          NaN  ...          NaN          NaN          NaN          NaN
# 3          NaN  ...          NaN          NaN          NaN          NaN
# 4          NaN  ...          NaN          NaN          NaN          NaN
# 5          NaN  ...          NaN          NaN          NaN          NaN
# 6          NaN  ...          NaN          NaN          NaN          NaN
# 7          NaN  ...          NaN          NaN          NaN          NaN
# 8          NaN  ...          NaN          NaN          NaN          NaN
# 9          NaN  ...          NaN          NaN          NaN          NaN
# 10         NaN  ...          NaN          NaN          NaN          NaN
# 11         NaN  ...          NaN          NaN          NaN          NaN
# 12         NaN  ...          NaN          NaN          NaN          NaN
# 13         NaN  ...          NaN          NaN          NaN          NaN
# 14         NaN  ...          NaN          NaN          NaN          NaN
# 15         NaN  ...          NaN          NaN          NaN          NaN
# 16         NaN  ...          NaN          NaN          NaN          NaN
# 17         NaN  ...          NaN          NaN          NaN          NaN
# 18         NaN  ...          NaN          NaN          NaN          NaN
# 19         NaN  ...          NaN          NaN          NaN          NaN
# 20         NaN  ...          NaN          NaN          NaN          NaN
# 21         NaN  ...          NaN          NaN          NaN          NaN
# 22         NaN  ...          NaN          NaN          NaN          NaN
# 23         NaN  ...          NaN          NaN          NaN          NaN
# 24         NaN  ...          NaN          NaN          NaN          NaN
# 25         NaN  ...          NaN          NaN          NaN          NaN
# 26         NaN  ...          NaN          NaN          NaN          NaN
# 27         NaN  ...          NaN          NaN          NaN          NaN
# 28         NaN  ...          NaN          NaN          NaN          NaN
# 29         NaN  ...          NaN          NaN          NaN          NaN
# 30         NaN  ...          NaN          NaN          NaN          NaN
# 31         NaN  ...          NaN          NaN          NaN          NaN
# 32         NaN  ...          NaN          NaN          NaN          NaN
# 33         NaN  ...          NaN          NaN          NaN          NaN
# 34         NaN  ...          NaN          NaN          NaN          NaN
# 35         NaN  ...          NaN          NaN          NaN          NaN
#
#     Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
# 13          NaN          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN          NaN
# 20          NaN          NaN          NaN          NaN          NaN
# 21          NaN          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25          NaN          NaN          NaN          NaN          NaN
# 26          NaN          NaN          NaN          NaN          NaN
# 27          NaN          NaN          NaN          NaN          NaN
# 28          NaN          NaN          NaN          NaN          NaN
# 29          NaN          NaN          NaN          NaN          NaN
# 30          NaN          NaN          NaN          NaN          NaN
# 31          NaN          NaN          NaN          NaN          NaN
# 32          NaN          NaN          NaN          NaN          NaN
# 33          NaN          NaN          NaN          NaN          NaN
# 34          NaN          NaN          NaN          NaN          NaN
# 35          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 25
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
#
# [36 rows x 26 columns]

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter, XMLConverter, HTMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import BytesIO

def convert_pdf(path, format='text', codec='utf-8', password=''):
    rsrcmgr = PDFResourceManager()
    retstr = BytesIO()
    laparams = LAParams()
    if format == 'text':
        device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    elif format == 'html':
        device = HTMLConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    elif format == 'xml':
        device = XMLConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    else:
        raise ValueError('provide format, either text, html or xml!')
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue().decode()
    fp.close()
    device.close()
    retstr.close()
    return text

# %%
print(convert_pdf('certificate.pdf'))
# Out:
# СЕРТИФИКАТ
# СЕРТИФИКАТ
#
# подтверждает, что
#
# Дьячков Александр Геннадьевич,
# Дьячков Александр Геннадьевич,
#
# «Основы документационного обеспечения в работе техника-
# «Основы документационного обеспечения в работе техника-
#
# обучающий(ая)ся ГБПОУ КБТ,
#
# прослушал обучение по программе
#
# программиста»
# программиста»
#
# по специальности
#
# 09.02.05 Прикладная информатика
#
# Москва 2021
#
# ОП-008963

# %%
x = convert_pdf_to_txt('certificate.pdf')
x
# Out:
# 'СЕРТИФИКАТ\nСЕРТИФИКАТ\n\nподтверждает, что\n\nДьячков Александр Геннадьевич,\nДьячков Александр Геннадьевич,\n\n«Основы документационного обеспечения в работе техника-\n«Основы документационного обеспечения в работе техника-\n\nобучающий(ая)ся ГБПОУ КБТ,\n\nпрослушал обучение по программе\n\nпрограммиста»\nпрограммиста»\n\nпо специальности\n\n09.02.05 Прикладная информатика\n\nМосква 2021\n\nОП-008963\n\n\x0c'
